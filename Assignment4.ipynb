# %% [markdown]
# <a href="https://colab.research.google.com/github/N-Vaishnav9/ML-Assignment/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
import time

# Load CIFAR-10 data
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# Convert labels to one-hot encoding
train_labels = to_categorical(train_labels, num_classes=10)
test_labels = to_categorical(test_labels, num_classes=10)

# Problem 1.a: Single hidden layer NN

model_a = models.Sequential([
    layers.Flatten(input_shape=(32, 32, 3)),
    layers.Dense(512, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model_a.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

start_time = time.time()
history_a = model_a.fit(train_images, train_labels, epochs=20, validation_data=(test_images, test_labels))
end_time = time.time()

training_time_a = end_time - start_time
train_loss_a, train_acc_a = model_a.evaluate(train_images, train_labels)
test_loss_a, test_acc_a = model_a.evaluate(test_images, test_labels)

print("\nProblem 1.a:")
print("Training time:", training_time_a)
print("Training loss:", train_loss_a)
print("Training accuracy:", train_acc_a)
print("Evaluation loss:", test_loss_a)
print("Evaluation accuracy:", test_acc_a)

# Problem 1.b: Three hidden layers NN

model_b = models.Sequential([
    layers.Flatten(input_shape=(32, 32, 3)),
    layers.Dense(512, activation='relu'),
    layers.Dense(256, activation='relu'),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

model_b.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

start_time = time.time()
history_b = model_b.fit(train_images, train_labels, epochs=300, validation_data=(test_images, test_labels))
end_time = time.time()

training_time_b = end_time - start_time
train_loss_b, train_acc_b = model_b.evaluate(train_images, train_labels)
test_loss_b, test_acc_b = model_b.evaluate(test_images, test_labels)

print("\nProblem 1.b:")
print("Training time:", training_time_b)
print("Training loss:", train_loss_b)
print("Training accuracy:", train_acc_b)
print("Evaluation loss:", test_loss_b)
print("Evaluation accuracy:", test_acc_b)
# Out:
# ...
# 170498071/170498071 [==============================] - 2s 0us/step
# Epoch 1/20
# 1563/1563 [==============================] - 41s 26ms/step - loss: 1.8861 - accuracy: 0.3285 - val_loss: 1.7542 - val_accuracy: 0.3728
# Epoch 2/20
# 1563/1563 [==============================] - 35s 23ms/step - loss: 1.7077 - accuracy: 0.3883 - val_loss: 1.7073 - val_accuracy: 0.3977
# Epoch 3/20
# 1563/1563 [==============================] - 35s 23ms/step - loss: 1.6520 - accuracy: 0.4097 - val_loss: 1.6113 - val_accuracy: 0.4341
# Epoch 4/20
# 1563/1563 [==============================] - 34s 22ms/step - loss: 1.6002 - accuracy: 0.4279 - val_loss: 1.5888 - val_accuracy: 0.4372
# Epoch 5/20
# 1563/1563 [==============================] - 36s 23ms/step - loss: 1.5701 - accuracy: 0.4424 - val_loss: 1.6166 - val_accuracy: 0.4193
# Epoch 6/20
# 1563/1563 [==============================] - 37s 24ms/step - loss: 1.5511 - accuracy: 0.4475 - val_loss: 1.5615 - val_accuracy: 0.4438
# Epoch 7/20
# ...
